# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.barplot(x=['A','B','C'],y=[1,3,2])
plt.show()

# %% [markdown]
# # Set

# %%
#Permite setear el estilo al grafico
sns.set(style='darkgrid',palette='dark',font='Verdana',font_scale=1)
sns.barplot(x=['A','B','C'],y=[1,3,2])
plt.show()
