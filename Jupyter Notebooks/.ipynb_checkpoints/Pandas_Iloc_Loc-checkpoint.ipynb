# %%
import pandas as pd
import os

# %%
os.getcwd()
os.chdir("C:\\Users\\joaqu\\OneDrive\\Escritorio\\Diplomatura Data Science\\Dataframes")
os.getcwd()
# Out:
# 'C:\\Users\\joaqu\\OneDrive\\Escritorio\\Diplomatura Data Science\\Dataframes'

# %%
df = pd.read_csv("bestsellers.csv",names=["Nombre","Autor","Rating","Reviews","Precio","Año","Genero"],header = 0) #Modificamos las columnas

# %%
df
# Out:
#                                                 Nombre  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                         Autor  Rating  Reviews  Precio   Año       Genero
# 0                    JJ Smith     4.7    17350       8  2016  Non Fiction
# 1                Stephen King     4.6     2052      22  2011      Fiction
# 2          Jordan B. Peterson     4.7    18979      15  2018  Non Fiction
# ...

# %%
df[0:4]
# Out:
#                                     Nombre               Autor  Rating  \
# 0            10-Day Green Smoothie Cleanse            JJ Smith     4.7
# 1                        11/22/63: A Novel        Stephen King     4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson     4.7
# 3                   1984 (Signet Classics)       George Orwell     4.7
#
#    Reviews  Precio   Año       Genero
# 0    17350       8  2016  Non Fiction
# 1     2052      22  2011      Fiction
# 2    18979      15  2018  Non Fiction
# 3    21424       6  2017      Fiction

# %%
df[["Nombre","Autor","Año"]]
# Out:
#                                                 Nombre  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                         Autor   Año
# 0                    JJ Smith  2016
# 1                Stephen King  2011
# 2          Jordan B. Peterson  2018
# 3               George Orwell  2017
# 4    National Geographic Kids  2019
# ..                        ...   ...
# 545               Jeff Kinney  2019
# ...

# %% [markdown]
# ## Loc

# %%
df.loc[:]
# Out:
#                                                 Nombre  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                         Autor  Rating  Reviews  Precio   Año       Genero
# 0                    JJ Smith     4.7    17350       8  2016  Non Fiction
# 1                Stephen King     4.6     2052      22  2011      Fiction
# 2          Jordan B. Peterson     4.7    18979      15  2018  Non Fiction
# ...

# %%
df.loc[0:4,["Nombre","Autor"]] #Permite flitrar mediante los nombres de las columnas
# Out:
#                                               Nombre                     Autor
# 0                      10-Day Green Smoothie Cleanse                  JJ Smith
# 1                                  11/22/63: A Novel              Stephen King
# 2            12 Rules for Life: An Antidote to Chaos        Jordan B. Peterson
# 3                             1984 (Signet Classics)             George Orwell
# 4  5,000 Awesome Facts (About Everything!) (Natio...  National Geographic Kids

# %%
df.loc[:,["Reviews"]] * -1
# Out:
#      Reviews
# 0     -17350
# 1      -2052
# 2     -18979
# 3     -21424
# 4      -7665
# ..       ...
# 545    -9413
# 546   -14331
# 547   -14331
# 548   -14331
# 549   -14331
#
# [550 rows x 1 columns]

# %%
df.loc[:,["Autor"]] == "JJ Smith"
# Out:
#      Autor
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# ..     ...
# 545  False
# 546  False
# 547  False
# 548  False
# 549  False
#
# [550 rows x 1 columns]

# %% [markdown]
# ## Iloc

# %%
df.iloc[:,0:3] #Podes pedir mediante los indices de la columnas
# Out:
#                                                 Nombre  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                         Autor  Rating
# 0                    JJ Smith     4.7
# 1                Stephen King     4.6
# 2          Jordan B. Peterson     4.7
# 3               George Orwell     4.7
# 4    National Geographic Kids     4.8
# ..                        ...     ...
# ...

# %%
df.iloc[:2,2:]
# Out:
#    Rating  Reviews  Precio   Año       Genero
# 0     4.7    17350       8  2016  Non Fiction
# 1     4.6     2052      22  2011      Fiction

# %% [markdown]
# ## Genero un dataframe con los precios iguales a 8

# %%
df_precio = df.loc[df["Precio"]==8]
df_precio
# Out:
#                                                 Nombre  \
# 0                        10-Day Green Smoothie Cleanse
# 9                            A Man Called Ove: A Novel
# 10                           A Man Called Ove: A Novel
# 18   Adult Coloring Books: A Coloring Book for Adul...
# 39   Broke: The Plan to Restore Our Trust, Truth an...
# 53       Crazy Rich Asians (Crazy Rich Asians Trilogy)
# 61   Dead in the Family (Sookie Stackhouse/True Blo...
# 82   Dog Man: A Tale of Two Kitties: From the Creat...
# 85   Dog Man: Fetch-22: From the Creator of Captain...
# 86   Dog Man: For Whom the Ball Rolls: From the Cre...
# 100                                     Fahrenheit 451
# 101                                     Fahrenheit 451
# 187  Jesus Calling: Enjoying Peace in His Presence ...
# 188  Jesus Calling: Enjoying Peace in His Presence ...
# 189  Jesus Calling: Enjoying Peace in His Presence ...
# 190  Jesus Calling: Enjoying Peace in His Presence ...
# ...
